# %%
import pandas as pd
import numpy as np
import random

from deap import base
from deap import creator
from deap import tools
from deap import algorithms

# %%
pessoas = [
    {"nome": "João", "origem": "CWB", "destino": "GRU"},
    {"nome": "Maria", "origem": "GIG", "destino": "GRU"},
    {"nome": "Pedro", "origem": "POA", "destino": "GRU"},
    {"nome": "Ana", "origem": "FLN", "destino": "GRU"},
    {"nome": "José", "origem": "CNF", "destino": "GRU"},
    {"nome": "Paulo", "origem": "GYN", "destino": "GRU"},
]

df_pessoas = pd.DataFrame(pessoas)

# %%
with open("voos.txt") as f:
    voos_data = [line.rstrip() for line in f]

keys = ["origem", "destino", "horario_partida", "horario_chegada", "valor"]
voos_list = [dict(zip(keys, voo.split(","))) for voo in voos_data]

df_voos = pd.DataFrame(voos_list)
df_voos["valor"] = df_voos["valor"].astype(float)
df_voos.reset_index(inplace=True)

# calculando o tempo de voo em minutos

df_voos["horario_partida_minutos"] = df_voos["horario_partida"].str.split(":").str[
    0
].astype(int) * 60 + df_voos["horario_partida"].str.split(":").str[1].astype(int)
df_voos["horario_chegada_minutos"] = df_voos["horario_chegada"].str.split(":").str[
    0
].astype(int) * 60 + df_voos["horario_chegada"].str.split(":").str[1].astype(int)
df_voos["tempo_voo"] = (
    df_voos["horario_chegada_minutos"] - df_voos["horario_partida_minutos"]
)

# %%
def imprime_agenda(individuo):
    print("Agenda:") 
    return df_voos[df_voos["index"].astype(int).isin(individuo)]

# %%
def avaliacao(individuo):
    df_temp = df_voos[df_voos["index"].isin(individuo)].copy()

    preco_total = df_temp["valor"].sum()
    ultima_chegada = df_temp["horario_chegada_minutos"].max()

    primeira_partida = df_temp["horario_partida_minutos"].min()

    df_temp['tempo_espera'] = (ultima_chegada - df_temp["horario_chegada_minutos"]) + (
        df_temp["horario_partida_minutos"] - primeira_partida
    )

    if ultima_chegada > primeira_partida:
        preco_total += 100

    total_espera = df_temp["tempo_espera"].sum()

    return (preco_total + total_espera,)

# %%
def inicializacao_par_voos(origem, destino):
    ida_valida = np.random.choice(
        df_voos.loc[
            (df_voos["origem"] == origem) & (df_voos["destino"] == destino)
        ].index
    ).tolist()
    volta_valida = np.random.choice(
        df_voos.loc[
            (df_voos["origem"] == destino) & (df_voos["destino"] == origem)
        ].index
    ).tolist()
    return ida_valida, volta_valida

# %%
def cxHalfAndHalf(ind1, ind2):

    size = min(len(ind1), len(ind2))
    cxpoint = size // 2 

    ind1[cxpoint:], ind2[cxpoint:] = ind2[cxpoint:], ind1[cxpoint:]

    return ind1, ind2

# %%
def mut_voos(individual):
    index = 2 * random.randint(0, len(individual) // 2 - 1)
    
    voo_ida = df_voos.iloc[individual[index]]
    origem, destino = voo_ida['origem'], voo_ida['destino']

    nova_ida = df_voos[(df_voos['origem'] == origem) & (df_voos['destino'] == destino)].sample(n=1).index.item()
    nova_volta = df_voos[(df_voos['origem'] == destino) & (df_voos['destino'] == origem)].sample(n=1).index.item()
        
    individual[index] = nova_ida
    individual[index + 1] = nova_volta
    
    return individual,

# %%
def create_individual(df_pessoas):
    individual = []
    for _, origem, destino in df_pessoas.itertuples(index=False):
        individual.extend(inicializacao_par_voos(origem, destino))
    return creator.Individual(individual)

# %%
# setup deap

# o individuo é uma lista de voos, cada voo é um dicionario
# a cada 2 voos, temos 1 pessoa ida e volta

creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()

# individuo
toolbox.register("individual", create_individual, df_pessoas)
# populacao
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
# avaliacao
toolbox.register("evaluate", avaliacao)
# crossover
toolbox.register("mate", tools.cxTwoPoint)
# mutacao
toolbox.register("mutate", mut_voos)
# selecao
toolbox.register("select", tools.selTournament, tournsize=3)

# %%
if __name__ == "__main__":
    populacao = toolbox.population(n=300)

    CXPB, MUTPB, NGEN = 0.5 , 0.1, 200
    estatisticas = tools.Statistics(key=lambda individuo: individuo.fitness.values)
    estatisticas.register("min", np.min)

    populacao, info = algorithms.eaSimple(
        population=populacao,
        toolbox=toolbox,
        cxpb=CXPB,
        mutpb=MUTPB,
        ngen=NGEN,
        stats=estatisticas,
        verbose=False,
    )

    populacao, info
    melhores = tools.selBest(populacao, k=1)

# %%
info
# Out:
# [{'gen': 0, 'nevals': 300, 'min': 7419.0},
#  {'gen': 1, 'nevals': 179, 'min': 7256.0},
#  {'gen': 2, 'nevals': 180, 'min': 7256.0},
#  {'gen': 3, 'nevals': 143, 'min': 7070.0},
#  {'gen': 4, 'nevals': 146, 'min': 6698.0},
#  {'gen': 5, 'nevals': 173, 'min': 5666.0},
#  {'gen': 6, 'nevals': 160, 'min': 5095.0},
#  {'gen': 7, 'nevals': 157, 'min': 5095.0},
#  {'gen': 8, 'nevals': 154, 'min': 5154.0},
#  {'gen': 9, 'nevals': 153, 'min': 3991.0},
#  {'gen': 10, 'nevals': 169, 'min': 3991.0},
#  {'gen': 11, 'nevals': 174, 'min': 3991.0},
#  {'gen': 12, 'nevals': 154, 'min': 3991.0},
#  {'gen': 13, 'nevals': 148, 'min': 3991.0},
#  {'gen': 14, 'nevals': 160, 'min': 3870.0},
#  {'gen': 15, 'nevals': 185, 'min': 3712.0},
#  {'gen': 16, 'nevals': 171, 'min': 3712.0},
#  {'gen': 17, 'nevals': 183, 'min': 3712.0},
#  {'gen': 18, 'nevals': 153, 'min': 3591.0},
#  {'gen': 19, 'nevals': 169, 'min': 3591.0},
#  {'gen': 20, 'nevals': 161, 'min': 3543.0},
#  {'gen': 21, 'nevals': 155, 'min': 3543.0},
#  {'gen': 22, 'nevals': 158, 'min': 3543.0},
#  {'gen': 23, 'nevals': 151, 'min': 3502.0},
#  {'gen': 24, 'nevals': 171, 'min': 3502.0},
#  {'gen': 25, 'nevals': 174, 'min': 3502.0},
#  {'gen': 26, 'nevals': 154, 'min': 3502.0},
#  {'gen': 27, 'nevals': 161, 'min': 3502.0},
#  {'gen': 28, 'nevals': 151, 'min': 3502.0},
#  {'gen': 29, 'nevals': 172, 'min': 3502.0},
#  {'gen': 30, 'nevals': 175, 'min': 3502.0},
#  {'gen': 31, 'nevals': 157, 'min': 3502.0},
#  {'gen': 32, 'nevals': 170, 'min': 3502.0},
#  {'gen': 33, 'nevals': 160, 'min': 3502.0},
#  {'gen': 34, 'nevals': 183, 'min': 3502.0},
#  {'gen': 35, 'nevals': 160, 'min': 3502.0},
#  {'gen': 36, 'nevals': 180, 'min': 3502.0},
#  {'gen': 37, 'nevals': 184, 'min': 3502.0},
#  {'gen': 38, 'nevals': 161, 'min': 3502.0},
#  {'gen': 39, 'nevals': 172, 'min': 3502.0},
#  {'gen': 40, 'nevals': 165, 'min': 3502.0},
#  {'gen': 41, 'nevals': 167, 'min': 3502.0},
#  {'gen': 42, 'nevals': 174, 'min': 3502.0},
#  {'gen': 43, 'nevals': 164, 'min': 3502.0},
#  {'gen': 44, 'nevals': 157, 'min': 3502.0},
#  {'gen': 45, 'nevals': 156, 'min': 3460.0},
#  {'gen': 46, 'nevals': 177, 'min': 3460.0},
#  {'gen': 47, 'nevals': 173, 'min': 3460.0},
#  {'gen': 48, 'nevals': 146, 'min': 3460.0},
#  {'gen': 49, 'nevals': 186, 'min': 3460.0},
#  {'gen': 50, 'nevals': 163, 'min': 3460.0},
#  {'gen': 51, 'nevals': 163, 'min': 3460.0},
#  {'gen': 52, 'nevals': 177, 'min': 3460.0},
#  {'gen': 53, 'nevals': 173, 'min': 3460.0},
#  {'gen': 54, 'nevals': 160, 'min': 3460.0},
#  {'gen': 55, 'nevals': 169, 'min': 3460.0},
#  {'gen': 56, 'nevals': 153, 'min': 3460.0},
#  {'gen': 57, 'nevals': 156, 'min': 3460.0},
#  {'gen': 58, 'nevals': 171, 'min': 3460.0},
#  {'gen': 59, 'nevals': 164, 'min': 3460.0},
#  {'gen': 60, 'nevals': 169, 'min': 3460.0},
#  {'gen': 61, 'nevals': 173, 'min': 3460.0},
#  {'gen': 62, 'nevals': 165, 'min': 3460.0},
#  {'gen': 63, 'nevals': 155, 'min': 3460.0},
#  {'gen': 64, 'nevals': 175, 'min': 3460.0},
#  {'gen': 65, 'nevals': 169, 'min': 3460.0},
#  {'gen': 66, 'nevals': 171, 'min': 3460.0},
#  {'gen': 67, 'nevals': 156, 'min': 3460.0},
#  {'gen': 68, 'nevals': 169, 'min': 3460.0},
#  {'gen': 69, 'nevals': 186, 'min': 3460.0},
#  {'gen': 70, 'nevals': 171, 'min': 3460.0},
#  {'gen': 71, 'nevals': 176, 'min': 3460.0},
#  {'gen': 72, 'nevals': 166, 'min': 3460.0},
#  {'gen': 73, 'nevals': 159, 'min': 3460.0},
#  {'gen': 74, 'nevals': 184, 'min': 3460.0},
#  {'gen': 75, 'nevals': 170, 'min': 3460.0},
#  {'gen': 76, 'nevals': 151, 'min': 3460.0},
#  {'gen': 77, 'nevals': 180, 'min': 3460.0},
#  {'gen': 78, 'nevals': 160, 'min': 3460.0},
#  {'gen': 79, 'nevals': 154, 'min': 3460.0},
#  {'gen': 80, 'nevals': 171, 'min': 3460.0},
#  {'gen': 81, 'nevals': 141, 'min': 3460.0},
#  {'gen': 82, 'nevals': 165, 'min': 3460.0},
#  {'gen': 83, 'nevals': 147, 'min': 3460.0},
#  {'gen': 84, 'nevals': 163, 'min': 3460.0},
#  {'gen': 85, 'nevals': 166, 'min': 3460.0},
#  {'gen': 86, 'nevals': 162, 'min': 3460.0},
#  {'gen': 87, 'nevals': 159, 'min': 3460.0},
#  {'gen': 88, 'nevals': 164, 'min': 3460.0},
#  {'gen': 89, 'nevals': 154, 'min': 3460.0},
#  {'gen': 90, 'nevals': 155, 'min': 3460.0},
#  {'gen': 91, 'nevals': 159, 'min': 3460.0},
#  {'gen': 92, 'nevals': 175, 'min': 3460.0},
#  {'gen': 93, 'nevals': 173, 'min': 3460.0},
#  {'gen': 94, 'nevals': 172, 'min': 3460.0},
#  {'gen': 95, 'nevals': 138, 'min': 3460.0},
#  {'gen': 96, 'nevals': 167, 'min': 3460.0},
#  {'gen': 97, 'nevals': 173, 'min': 3460.0},
#  {'gen': 98, 'nevals': 135, 'min': 3460.0},
#  {'gen': 99, 'nevals': 167, 'min': 3460.0},
#  {'gen': 100, 'nevals': 169, 'min': 3460.0},
#  {'gen': 101, 'nevals': 178, 'min': 3460.0},
#  {'gen': 102, 'nevals': 167, 'min': 3460.0},
#  {'gen': 103, 'nevals': 171, 'min': 3460.0},
#  {'gen': 104, 'nevals': 180, 'min': 3460.0},
#  {'gen': 105, 'nevals': 169, 'min': 3460.0},
#  {'gen': 106, 'nevals': 159, 'min': 3460.0},
#  {'gen': 107, 'nevals': 154, 'min': 3460.0},
#  {'gen': 108, 'nevals': 165, 'min': 3460.0},
#  {'gen': 109, 'nevals': 166, 'min': 3460.0},
#  {'gen': 110, 'nevals': 150, 'min': 3460.0},
#  {'gen': 111, 'nevals': 165, 'min': 3460.0},
#  {'gen': 112, 'nevals': 153, 'min': 3460.0},
#  {'gen': 113, 'nevals': 157, 'min': 3460.0},
#  {'gen': 114, 'nevals': 168, 'min': 3460.0},
#  {'gen': 115, 'nevals': 156, 'min': 3460.0},
#  {'gen': 116, 'nevals': 164, 'min': 3460.0},
#  {'gen': 117, 'nevals': 172, 'min': 3460.0},
#  {'gen': 118, 'nevals': 179, 'min': 3460.0},
#  {'gen': 119, 'nevals': 168, 'min': 3460.0},
#  {'gen': 120, 'nevals': 153, 'min': 3460.0},
#  {'gen': 121, 'nevals': 166, 'min': 3460.0},
#  {'gen': 122, 'nevals': 160, 'min': 3460.0},
#  {'gen': 123, 'nevals': 150, 'min': 3460.0},
#  {'gen': 124, 'nevals': 164, 'min': 3460.0},
#  {'gen': 125, 'nevals': 179, 'min': 3460.0},
#  {'gen': 126, 'nevals': 172, 'min': 3460.0},
#  {'gen': 127, 'nevals': 177, 'min': 3460.0},
#  {'gen': 128, 'nevals': 151, 'min': 3460.0},
#  {'gen': 129, 'nevals': 179, 'min': 3460.0},
#  {'gen': 130, 'nevals': 157, 'min': 3460.0},
#  {'gen': 131, 'nevals': 158, 'min': 3460.0},
#  {'gen': 132, 'nevals': 152, 'min': 3460.0},
#  {'gen': 133, 'nevals': 197, 'min': 3460.0},
#  {'gen': 134, 'nevals': 160, 'min': 3460.0},
#  {'gen': 135, 'nevals': 157, 'min': 3460.0},
#  {'gen': 136, 'nevals': 172, 'min': 3460.0},
#  {'gen': 137, 'nevals': 185, 'min': 3460.0},
#  {'gen': 138, 'nevals': 147, 'min': 3460.0},
#  {'gen': 139, 'nevals': 173, 'min': 3460.0},
#  {'gen': 140, 'nevals': 159, 'min': 3460.0},
#  {'gen': 141, 'nevals': 167, 'min': 3460.0},
#  {'gen': 142, 'nevals': 167, 'min': 3460.0},
#  {'gen': 143, 'nevals': 192, 'min': 3460.0},
#  {'gen': 144, 'nevals': 173, 'min': 3460.0},
#  {'gen': 145, 'nevals': 167, 'min': 3460.0},
#  {'gen': 146, 'nevals': 162, 'min': 3460.0},
#  {'gen': 147, 'nevals': 170, 'min': 3460.0},
#  {'gen': 148, 'nevals': 185, 'min': 3460.0},
#  {'gen': 149, 'nevals': 181, 'min': 3460.0},
#  {'gen': 150, 'nevals': 167, 'min': 3460.0},
#  {'gen': 151, 'nevals': 174, 'min': 3460.0},
#  {'gen': 152, 'nevals': 162, 'min': 3460.0},
#  {'gen': 153, 'nevals': 163, 'min': 3460.0},
#  {'gen': 154, 'nevals': 178, 'min': 3460.0},
#  {'gen': 155, 'nevals': 149, 'min': 3460.0},
#  {'gen': 156, 'nevals': 158, 'min': 3460.0},
#  {'gen': 157, 'nevals': 193, 'min': 3460.0},
#  {'gen': 158, 'nevals': 161, 'min': 3460.0},
#  {'gen': 159, 'nevals': 159, 'min': 3460.0},
#  {'gen': 160, 'nevals': 150, 'min': 3460.0},
#  {'gen': 161, 'nevals': 167, 'min': 3460.0},
#  {'gen': 162, 'nevals': 169, 'min': 3460.0},
#  {'gen': 163, 'nevals': 175, 'min': 3460.0},
#  {'gen': 164, 'nevals': 156, 'min': 3460.0},
#  {'gen': 165, 'nevals': 177, 'min': 3460.0},
#  {'gen': 166, 'nevals': 165, 'min': 3460.0},
#  {'gen': 167, 'nevals': 180, 'min': 3460.0},
#  {'gen': 168, 'nevals': 160, 'min': 3460.0},
#  {'gen': 169, 'nevals': 167, 'min': 3460.0},
#  {'gen': 170, 'nevals': 169, 'min': 3460.0},
#  {'gen': 171, 'nevals': 164, 'min': 3460.0},
#  {'gen': 172, 'nevals': 143, 'min': 3460.0},
#  {'gen': 173, 'nevals': 172, 'min': 3460.0},
#  {'gen': 174, 'nevals': 148, 'min': 3460.0},
#  {'gen': 175, 'nevals': 179, 'min': 3460.0},
#  {'gen': 176, 'nevals': 168, 'min': 3460.0},
#  {'gen': 177, 'nevals': 179, 'min': 3460.0},
#  {'gen': 178, 'nevals': 152, 'min': 3460.0},
#  {'gen': 179, 'nevals': 177, 'min': 3460.0},
#  {'gen': 180, 'nevals': 184, 'min': 3460.0},
#  {'gen': 181, 'nevals': 162, 'min': 3460.0},
#  {'gen': 182, 'nevals': 163, 'min': 3460.0},
#  {'gen': 183, 'nevals': 164, 'min': 3460.0},
#  {'gen': 184, 'nevals': 160, 'min': 3460.0},
#  {'gen': 185, 'nevals': 158, 'min': 3460.0},
#  {'gen': 186, 'nevals': 172, 'min': 3460.0},
#  {'gen': 187, 'nevals': 147, 'min': 3460.0},
#  {'gen': 188, 'nevals': 176, 'min': 3460.0},
#  {'gen': 189, 'nevals': 175, 'min': 3460.0},
#  {'gen': 190, 'nevals': 162, 'min': 3460.0},
#  {'gen': 191, 'nevals': 185, 'min': 3460.0},
#  {'gen': 192, 'nevals': 156, 'min': 3460.0},
#  {'gen': 193, 'nevals': 155, 'min': 3460.0},
#  {'gen': 194, 'nevals': 155, 'min': 3460.0},
#  {'gen': 195, 'nevals': 161, 'min': 3460.0},
#  {'gen': 196, 'nevals': 164, 'min': 3460.0},
#  {'gen': 197, 'nevals': 164, 'min': 3460.0},
#  {'gen': 198, 'nevals': 136, 'min': 3460.0},
#  {'gen': 199, 'nevals': 178, 'min': 3460.0},
#  {'gen': 200, 'nevals': 163, 'min': 3460.0}]

# %%
melhores[0]
# Out:
# [67, 66, 87, 86, 109, 106, 47, 46, 29, 26, 9, 6]

# %%
imprime_agenda(melhores[0])
# Out:
# Agenda:
#      index origem destino horario_partida horario_chegada  valor  \
# 6        6    GRU     GYN           11:07           13:24  171.0
# 9        9    GYN     GRU           12:18           14:56  172.0
# 26      26    GRU     CNF           10:33           13:11  132.0
# 29      29    CNF     GRU           12:44           14:17  134.0
# 46      46    GRU     FLN           11:08           14:38  262.0
# 47      47    FLN     GRU           11:28           14:40  248.0
# 66      66    GRU     CWB           10:33           12:03   74.0
# 67      67    CWB     GRU           11:16           13:29   83.0
# 86      86    GRU     GIG           10:51           14:16  256.0
# 87      87    GIG     GRU           10:30           14:57  290.0
# 106    106    GRU     POA           10:32           13:16  139.0
# 109    109    POA     GRU           12:08           14:59  149.0
#
#      horario_partida_minutos  horario_chegada_minutos  tempo_voo
# 6                        667                      804        137
# 9                        738                      896        158
# 26                       633                      791        158
# 29                       764                      857         93
# 46                       668                      878        210
# 47                       688                      880        192
# 66                       633                      723         90
# 67                       676                      809        133
# 86                       651                      856        205
# 87                       630                      897        267
# 106                      632                      796        164
# 109                      728                      899        171
